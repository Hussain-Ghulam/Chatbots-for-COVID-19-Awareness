# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle

import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD
import random


import nltk
nltk.download('punkt')

import nltk
nltk.download('wordnet')

words=[]
classes = []
documents = []
ignore_words = ['?', '!']
# data_file = open('intents.json').read()
# intents = json.loads(data_file)

with open(r"json_data.json","r") as json_data:
    intents = json.load(json_data)


for intent in intents['intents']:
    for pattern in intent['patterns']:

        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w, intent['tag']))

        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# lemmaztize and lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
# sort classes
# classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)


pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))

# create our training data
training = []
# create an empty array for our output
output_empty = [0] * len(classes)
# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    
    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")


# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(256, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

model.summary()
# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)

####epochs
no_epochs=200
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=no_epochs, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)

print("model created")



import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import pickle
import numpy as np

from keras.models import load_model
model = load_model('chatbot_model.h5')
import json
import random


with open(r"json_data.json","r") as json_data:
    intents = json.load(json_data)

words = pickle.load(open('words.pkl','rb'))
classes = pickle.load(open('classes.pkl','rb'))
from collections import defaultdict

dic=defaultdict(str)


qs=["Hi","Hello","Good Morning"]
dic["Hi"]="Hi, I am ChatBot, How can I help you?"
dic["Hello"]="Hello, I am ChatBot, How can I help you?"
dic["Good Morning"]="Good Morning, I wish you a good day, How can I help you?"


def clean_up_sentence(sentence):
    # tokenize the pattern - split words into array
    sentence_words = nltk.word_tokenize(sentence)
    # stem each word - create short form for word
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words

# return bag of words array: 0 or 1 for each word in the bag that exists in the sentence

def bow(sentence, words, show_details=True):
    # tokenize the pattern
    sentence_words = clean_up_sentence(sentence)
    # print(sentence_words)
    # bag of words - matrix of N words, vocabulary matrix
    bag = [0]*len(words)  
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s: 
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))

def predict_class(sentence, model):
    # filter out predictions below a threshold
    p = bow(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    # print("Model result: ", res)
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    # print("results are: ", results)
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            # print("our tag ",tag)
            # print("i: ", i['tag'], i['responses'])
            # print("i[responses]: ")
            # print(i['responses'])
            break
    return result

def chatbot_response(msg):
    ints = predict_class(msg, model)
    # print("ints are: ", ints)
    if len(ints)==0:
      return "Sorry, I didn't get you, can you please ask in another way?"
    res = getResponse(ints, intents)
    return res


print("---------------------------------Chtabot starts----------------------\n")
print("------------------------If you want to stop chatting, enter exit-------------\n")
while True:
  s=input()
  if s=='exit':
    break
  if s in qs:
    print(dic[s])
  else:
    s=s.strip()
    res=chatbot_response(s)
    print(res)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ghussain\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ghussain\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# 206 documents
# 110 classes [['incubation_corona'], ['corona'], ['symptoms_corona'], ['vaccine'], ['treatment_corona'], ['protect'], ['worker_risk'], ['WHO'], ['risk_corona'], ['test_doctor'], ['covid_SARS'], ['SARS'], ['transmission_corona'], ['infectious'], ['infection'], ['risk'], ['risk_transmission'], ['risk_pregnant'], ['test_covid'], ['test'], ['allergy_covid'], ['allergy_symptoms'], ['avoid_infecting'], ['distancing'], ['mask_covid'], ['covid_influenza'], ['europe_covid'], ['EU'], ['peak'], ['schools'], ['restriction'], ['travel'], ['food'], ['animal'], ['lung'], ['measure'], ['isolate'], ['safe'], ['covid'], ['fever'], ['mask'], ['smoke'], ['condition'], ['flu_vaccine'], ['vulnerable'], ['Europe'], ['faces'], ['catch'], ['worry'], ['antibiotic'], ['medicine'], ['incubation'], ['package'], ['not_do'], ['symptoms'], ['second'], ['virus'], ['illness'], ['again'], ['spread'], ['medical'], ['reduce_infection'], ['ibuprofen'], ['house'], ['medical_appointment'], ['home'], ['worker home'], ['work'], ['friends'], ['relatives'], ['park'], ['drive'], ['rules'], ['intercollegiate'], ['teaching'], ['pregnant'], ['baby'], ['appointment'], [' pregnant'], ['child'], ['birth'], ['testing'], ['labour'], ['corona_virus'], ['stigma'], ['rise'], ['weather'], ['community'], ['temperature'], ['mosquitoes'], ['contact'], ['donate'], ['child_covid'], ['child_mask'], ['family'], ['sick'], ['sanitizer'], ['risk corona'], ['prevent'], ['treatment'], ['transmitted'], ['animlas'], ['pets'], ['incubarion'], ['worry_covid'], ['use_of_mask'], ['animal_source'], ['pet'], ['government'], ['information']]
# 448 unique lemmatized words ['(', ')', ',', '.', '14', '2019', ';', 'a', 'able', 'about', 'accurate', 'additional', 'adult', 'advice', 'affect', 'affected', 'after', 'again', 'against', 'age', 'air', 'allergy', 'allowed', 'also', 'am', 'an', 'and', 'animal', 'another', 'antenatal', 'antibiotic', 'any', 'anything', 'appointment', 'are', 'area', 'asked', 'at', 'attend', 'attention', 'available', 'avoid', 'baby', 'be', 'because', 'become', 'becoming', 'been', 'being', 'between', 'birth', 'blame', 'blood', 'both', 'break', 'by', 'ca', 'caesarean', 'called', 'can', 'cancer', 'care', 'case', 'catch', 'catching', 'caught', 'cause', 'cdc', 'centre', 'chain', 'child', 'childbirth', 'china', 'choice', 'cleaning', 'close', 'closed', 'come', 'community', 'comparable', 'complication', 'condition', 'confirmed', 'consider', 'contact', 'contain', 'continuing', 'control', 'corona', 'coronavirus', 'cough', 'could', 'country', 'covering', 'covid-19', 'covid19', 'create', 'critical', 'crowded', 'cure', 'day', 'dentist', 'detailed', 'develop', 'developing', 'diagnosed', 'die', 'different', 'differentiate', 'disease', 'dispose', 'distancing', 'distinguish', 'do', 'doctor', 'doe', 'doesn', 'doing', 'donate', 'done', 'drive', 'drug', 'dry', 'during', 'e.g', 'effect', 'effective', 'elderly', 'essential', 'etc', 'eu', 'eu/eea', 'europe', 'european', 'every', 'exhaled', 'face', 'family', 'fda-approved', 'feces', 'feel', 'fever', 'fever/pollen', 'find', 'flu', 'food', 'for', 'friend', 'from', 'frozen', 'garden', 'general', 'germ', 'get', 'getting', 'give', 'go', 'government', 'gp', 'green', 'group', 'ha', 'had', 'hall', 'hand', 'handling', 'happen', 'happens', 'have', 'having', 'hay', 'health', 'help', 'high', 'higher', 'home', 'house', 'how', 'human', 'i', 'ibuprofen', 'if', 'illness', 'impact', 'imported', 'in', 'including', 'incubation', 'individual', 'induced', 'infected', 'infecting', 'infection', 'infectious', 'influenza', 'information', 'instrumental', 'intercollegiate', 'into', 'is', 'isolate', 'it', 'kill', 'know', 'labour', 'last', 'leave', 'like', 'likely', 'limit', 'live', 'logistics', 'long', 'lung', 'm', 'major', 'make', 'managed', 'many', 'mask', 'me', 'measure', 'median', 'medical', 'medicine', 'member', 'might', 'mode', 'moment', 'more', 'mosquito', 'most', 'move', 'my', 'myself', "n't", 'national', 'need', 'neighbour', 'neonate', 'news', 'no', 'not', 'novel', 'obtain', 'occurs', 'of', 'off', 'often', 'okay', 'older', 'on', 'one', 'open', 'operating', 'opposed', 'or', 'organisation', 'other', 'others', 'our', 'out', 'outbreak', 'outside', 'own', 'package', 'packaged', 'pandemic', 'park', 'part', 'partner', 'pas', 'past', 'peak', 'people', 'period', 'person', 'pet', 'physical', 'plane', 'please', 'pollen', 'population', 'positive', 'possible', 'postnatal', 'potential', 'pre-existing', 'precaution', 'pregnancy', 'pregnant', 'prepare', 'prepared', 'prevent', 'preventing', 'product', 'protect', 'protected', 'protecting', 'protection', 'provide', 'provided', 'put', 'receive', 'recently', 'recommend', 'recommendation', 'recovered', 'reduce', 'reducing', 'refer', 'refrigerated', 'regularly', 'related', 'relative', 'reported', 'residence', 'respiratory', 'restaurant', 'restriction', 'retail', 'rise', 'risk', 'role', 'rule', 'safe', 'same', 'sanitizer', 'sars', 'sars-cov-2', 'say', 'school', 'scientific', 'seasonal', 'second', 'see', 'seeing', 'self', 'self-isolate', 'self-isolating', 'self-isolation', 'serious', 'service', 'setting', 'severe', 'shipping', 'should', 'show', 'sick', 'situation', 'smoke', 'soap', 'social', 'some', 'somebody', 'someone', 'source', 'space', 'spread', 'spreading', 'standpoint', 'stay', 'step', 'stigma', 'stop', 'store', 'student', 'suffer', 'suffering', 'supply', 'surface', 'survive', 'suspected', 'symptom', 't', 'take', 'taken', 'teaching', 'temperature', 'test', 'tested', 'than', 'that', 'the', 'theatre', 'their', 'therapy', 'there', 'these', 'they', 'this', 'those', 'through', 'time', 'to', 'transmission', 'transmi ...
# Training data created
# C:\Users\ghussain\AppData\Local\Temp\ipykernel_10648\2111335423.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   training = np.array(training)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               114944
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 110)               14190
#
# =================================================================
# Total params: 162,030
# Trainable params: 162,030
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# C:\Users\ghussain\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\gradient_descent.py:108: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 42/42 [==============================] - 1s 3ms/step - loss: 4.7013 - accuracy: 0.0194
# Epoch 2/200
# 42/42 [==============================] - 0s 2ms/step - loss: 4.5534 - accuracy: 0.0583
# Epoch 3/200
# 42/42 [==============================] - 0s 3ms/step - loss: 4.3192 - accuracy: 0.0825
# Epoch 4/200
# 42/42 [==============================] - 0s 3ms/step - loss: 4.1936 - accuracy: 0.0971
# Epoch 5/200
# 42/42 [==============================] - 0s 2ms/step - loss: 3.9425 - accuracy: 0.1748
# Epoch 6/200
# 42/42 [==============================] - 0s 3ms/step - loss: 3.7869 - accuracy: 0.1699
# Epoch 7/200
# 42/42 [==============================] - 0s 3ms/step - loss: 3.5500 - accuracy: 0.2233
# Epoch 8/200
# 42/42 [==============================] - 0s 3ms/step - loss: 3.3326 - accuracy: 0.2816
# Epoch 9/200
# 42/42 [==============================] - 0s 3ms/step - loss: 3.2064 - accuracy: 0.2621
# Epoch 10/200
# 42/42 [==============================] - 0s 2ms/step - loss: 2.7935 - accuracy: 0.3689
# Epoch 11/200
# 42/42 [==============================] - 0s 2ms/step - loss: 2.8918 - accuracy: 0.3544
# Epoch 12/200
# 42/42 [==============================] - 0s 2ms/step - loss: 2.4569 - accuracy: 0.4320
# Epoch 13/200
# 42/42 [==============================] - 0s 3ms/step - loss: 2.4029 - accuracy: 0.3981
# Epoch 14/200
# 42/42 [==============================] - 0s 3ms/step - loss: 2.2356 - accuracy: 0.4515
# Epoch 15/200
# 42/42 [==============================] - 0s 2ms/step - loss: 2.0155 - accuracy: 0.5049
# Epoch 16/200
# 42/42 [==============================] - 0s 2ms/step - loss: 1.9452 - accuracy: 0.5097
# Epoch 17/200
# 42/42 [==============================] - 0s 2ms/step - loss: 1.8848 - accuracy: 0.5340
# Epoch 18/200
# 42/42 [==============================] - 0s 2ms/step - loss: 1.7633 - accuracy: 0.5291
# Epoch 19/200
# 42/42 [==============================] - 0s 3ms/step - loss: 1.5431 - accuracy: 0.6019
# Epoch 20/200
# 42/42 [==============================] - 0s 3ms/step - loss: 1.6452 - accuracy: 0.5777
# Epoch 21/200
# 42/42 [==============================] - 0s 3ms/step - loss: 1.4984 - accuracy: 0.6214
# Epoch 22/200
# 42/42 [==============================] - 0s 3ms/step - loss: 1.3876 - accuracy: 0.6311
# Epoch 23/200
# 42/42 [==============================] - 0s 3ms/step - loss: 1.3137 - accuracy: 0.6359
# Epoch 24/200
# 42/42 [==============================] - 0s 3ms/step - loss: 1.2728 - accuracy: 0.6990
# Epoch 25/200
# 42/42 [==============================] - 0s 3ms/step - loss: 1.2066 - accuracy: 0.6845
# Epoch 26/200
# 42/42 [==============================] - 0s 3ms/step - loss: 1.1422 - accuracy: 0.6942
# Epoch 27/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.9726 - accuracy: 0.7524
# Epoch 28/200
# 42/42 [==============================] - 0s 2ms/step - loss: 1.0204 - accuracy: 0.7282
# Epoch 29/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.8604 - accuracy: 0.7670
# Epoch 30/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.8926 - accuracy: 0.7718
# Epoch 31/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.7732 - accuracy: 0.7864
# Epoch 32/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.9562 - accuracy: 0.7136
# Epoch 33/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.8154 - accuracy: 0.7670
# Epoch 34/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.8113 - accuracy: 0.7816
# Epoch 35/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.7590 - accuracy: 0.7864
# Epoch 36/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.7148 - accuracy: 0.8010
# Epoch 37/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.7526 - accuracy: 0.7816
# Epoch 38/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.7206 - accuracy: 0.7961
# Epoch 39/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.6033 - accuracy: 0.8252
# Epoch 40/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.6956 - accuracy: 0.8010
# Epoch 41/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.4897 - accuracy: 0.8641
# Epoch 42/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.5505 - accuracy: 0.8447
# Epoch 43/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.6888 - accuracy: 0.7767
# Epoch 44/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.5995 - accuracy: 0.8350
# Epoch 45/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.5157 - accuracy: 0.8592
# Epoch 46/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.5126 - accuracy: 0.8544
# Epoch 47/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.6445 - accuracy: 0.8155
# Epoch 48/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.5834 - accuracy: 0.8204
# Epoch 49/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.5025 - accuracy: 0.8544
# Epoch 50/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.5929 - accuracy: 0.8350
# Epoch 51/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.4462 - accuracy: 0.8641
# Epoch 52/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.5853 - accuracy: 0.8301
# Epoch 53/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.4312 - accuracy: 0.8592
# Epoch 54/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.4853 - accuracy: 0.8641
# Epoch 55/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.6161 - accuracy: 0.8592
# Epoch 56/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.4639 - accuracy: 0.8301
# Epoch 57/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.4736 - accuracy: 0.8544
# Epoch 58/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.4790 - accuracy: 0.8883
# Epoch 59/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.4331 - accuracy: 0.8738
# Epoch 60/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.4276 - accuracy: 0.8689
# Epoch 61/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.6279 - accuracy: 0.8252
# Epoch 62/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.4520 - accuracy: 0.8738
# Epoch 63/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.4549 - accuracy: 0.8495
# Epoch 64/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.4635 - accuracy: 0.8592
# Epoch 65/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.4682 - accuracy: 0.8883
# Epoch 66/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3391 - accuracy: 0.8981
# Epoch 67/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3817 - accuracy: 0.8786
# Epoch 68/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.4267 - accuracy: 0.8981
# Epoch 69/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.4322 - accuracy: 0.8641
# Epoch 70/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.4040 - accuracy: 0.8786
# Epoch 71/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.4017 - accuracy: 0.8689
# Epoch 72/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3755 - accuracy: 0.8835
# Epoch 73/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3334 - accuracy: 0.8981
# Epoch 74/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.4207 - accuracy: 0.8835
# Epoch 75/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3092 - accuracy: 0.9078
# Epoch 76/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.3968 - accuracy: 0.8786
# Epoch 77/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.3498 - accuracy: 0.8883
# Epoch 78/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.4137 - accuracy: 0.8738
# Epoch 79/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.4403 - accuracy: 0.8689
# Epoch 80/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.3080 - accuracy: 0.8932
# Epoch 81/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3200 - accuracy: 0.9029
# Epoch 82/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2639 - accuracy: 0.9078
# Epoch 83/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.3540 - accuracy: 0.8883
# Epoch 84/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3377 - accuracy: 0.8835
# Epoch 85/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.3285 - accuracy: 0.8835
# Epoch 86/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3181 - accuracy: 0.8786
# Epoch 87/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2701 - accuracy: 0.9029
# Epoch 88/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3467 - accuracy: 0.8786
# Epoch 89/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3665 - accuracy: 0.8835
# Epoch 90/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.3117 - accuracy: 0.8689
# Epoch 91/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.3373 - accuracy: 0.8835
# Epoch 92/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3517 - accuracy: 0.8981
# Epoch 93/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3490 - accuracy: 0.8932
# Epoch 94/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.3236 - accuracy: 0.9078
# Epoch 95/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.4104 - accuracy: 0.8592
# Epoch 96/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.3214 - accuracy: 0.9126
# Epoch 97/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.3188 - accuracy: 0.9126
# Epoch 98/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3394 - accuracy: 0.8883
# Epoch 99/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3317 - accuracy: 0.9078
# Epoch 100/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.3044 - accuracy: 0.9078
# Epoch 101/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2789 - accuracy: 0.9126
# Epoch 102/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2771 - accuracy: 0.8932
# Epoch 103/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.3630 - accuracy: 0.8786
# Epoch 104/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2464 - accuracy: 0.9320
# Epoch 105/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2466 - accuracy: 0.9320
# Epoch 106/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.3161 - accuracy: 0.8689
# Epoch 107/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2622 - accuracy: 0.9078
# Epoch 108/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.3012 - accuracy: 0.8932
# Epoch 109/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3264 - accuracy: 0.8738
# Epoch 110/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3529 - accuracy: 0.8786
# Epoch 111/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3096 - accuracy: 0.9029
# Epoch 112/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.3360 - accuracy: 0.8932
# Epoch 113/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.3726 - accuracy: 0.8981
# Epoch 114/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2499 - accuracy: 0.9175
# Epoch 115/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2822 - accuracy: 0.9078
# Epoch 116/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2943 - accuracy: 0.8981
# Epoch 117/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2865 - accuracy: 0.9029
# Epoch 118/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2775 - accuracy: 0.8981
# Epoch 119/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.3465 - accuracy: 0.8932
# Epoch 120/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3555 - accuracy: 0.8883
# Epoch 121/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2721 - accuracy: 0.8981
# Epoch 122/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.3787 - accuracy: 0.8641
# Epoch 123/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3676 - accuracy: 0.8981
# Epoch 124/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3232 - accuracy: 0.8883
# Epoch 125/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.3082 - accuracy: 0.8786
# Epoch 126/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2887 - accuracy: 0.8981
# Epoch 127/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3334 - accuracy: 0.8883
# Epoch 128/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2399 - accuracy: 0.9078
# Epoch 129/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2786 - accuracy: 0.9078
# Epoch 130/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2846 - accuracy: 0.9029
# Epoch 131/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3813 - accuracy: 0.8883
# Epoch 132/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2601 - accuracy: 0.8835
# Epoch 133/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1820 - accuracy: 0.9466
# Epoch 134/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1808 - accuracy: 0.9515
# Epoch 135/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2340 - accuracy: 0.9223
# Epoch 136/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.3259 - accuracy: 0.9029
# Epoch 137/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2413 - accuracy: 0.9126
# Epoch 138/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2833 - accuracy: 0.8835
# Epoch 139/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2319 - accuracy: 0.9029
# Epoch 140/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2994 - accuracy: 0.8932
# Epoch 141/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2868 - accuracy: 0.9223
# Epoch 142/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2378 - accuracy: 0.9126
# Epoch 143/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2632 - accuracy: 0.8883
# Epoch 144/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2974 - accuracy: 0.8786
# Epoch 145/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2624 - accuracy: 0.9175
# Epoch 146/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2823 - accuracy: 0.9029
# Epoch 147/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2967 - accuracy: 0.9029
# Epoch 148/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2768 - accuracy: 0.9078
# Epoch 149/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3125 - accuracy: 0.8981
# Epoch 150/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2476 - accuracy: 0.8981
# Epoch 151/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2228 - accuracy: 0.9223
# Epoch 152/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.3221 - accuracy: 0.9029
# Epoch 153/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2754 - accuracy: 0.9078
# Epoch 154/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2261 - accuracy: 0.9320
# Epoch 155/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3143 - accuracy: 0.8981
# Epoch 156/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2576 - accuracy: 0.9223
# Epoch 157/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2686 - accuracy: 0.9223
# Epoch 158/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2548 - accuracy: 0.9175
# Epoch 159/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3050 - accuracy: 0.9029
# Epoch 160/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2873 - accuracy: 0.8932
# Epoch 161/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2584 - accuracy: 0.8981
# Epoch 162/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2507 - accuracy: 0.9175
# Epoch 163/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.3066 - accuracy: 0.8981
# Epoch 164/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2877 - accuracy: 0.8932
# Epoch 165/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2565 - accuracy: 0.9126
# Epoch 166/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.1879 - accuracy: 0.9272
# Epoch 167/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.1887 - accuracy: 0.9515
# Epoch 168/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2287 - accuracy: 0.9272
# Epoch 169/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2543 - accuracy: 0.9126
# Epoch 170/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2054 - accuracy: 0.9175
# Epoch 171/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.1754 - accuracy: 0.9272
# Epoch 172/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2168 - accuracy: 0.9223
# Epoch 173/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2927 - accuracy: 0.8786
# Epoch 174/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2816 - accuracy: 0.9126
# Epoch 175/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2500 - accuracy: 0.9223
# Epoch 176/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.1979 - accuracy: 0.9175
# Epoch 177/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2819 - accuracy: 0.9029
# Epoch 178/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2099 - accuracy: 0.9223
# Epoch 179/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2184 - accuracy: 0.9515
# Epoch 180/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2342 - accuracy: 0.9078
# Epoch 181/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.1974 - accuracy: 0.9272
# Epoch 182/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2823 - accuracy: 0.8932
# Epoch 183/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2417 - accuracy: 0.8981
# Epoch 184/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2284 - accuracy: 0.9126
# Epoch 185/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2177 - accuracy: 0.9078
# Epoch 186/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2173 - accuracy: 0.8883
# Epoch 187/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2168 - accuracy: 0.9272
# Epoch 188/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.1909 - accuracy: 0.9272
# Epoch 189/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.1902 - accuracy: 0.9369
# Epoch 190/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2941 - accuracy: 0.8786
# Epoch 191/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2688 - accuracy: 0.8932
# Epoch 192/200
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2060 - accuracy: 0.8835
# Epoch 193/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2268 - accuracy: 0.9126
# Epoch 194/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2208 - accuracy: 0.9078
# Epoch 195/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2405 - accuracy: 0.9126
# Epoch 196/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2380 - accuracy: 0.9175
# Epoch 197/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.1844 - accuracy: 0.9369
# Epoch 198/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2730 - accuracy: 0.9078
# Epoch 199/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2601 - accuracy: 0.9078
# Epoch 200/200
# 42/42 [==============================] - 0s 2ms/step - loss: 0.1536 - accuracy: 0.9320
# model created
# ---------------------------------Chtabot starts----------------------
#
# ------------------------If you want to stop chatting, enter exit-------------
#
# hi
# 1/1 [==============================] - 0s 53ms/step
# Sorry, I didn't get you, can you please ask in another way?
# corona
# 1/1 [==============================] - 0s 13ms/step
# People of all ages can be infected by the new corona virus (2019-nCoV). Older people, and people with pre-existing medical conditions (such as asthma, diabetes, heart disease) appear to be more vulnerable to becoming severely ill with the virus.WHO advises people of all ages to take steps to protect themselves from the virus, for example by following good hand hygiene and good respiratory hygiene.
# treatment
# 1/1 [==============================] - 0s 30ms/step
# Sorry, I didn't get you, can you please ask in another way?
# health
# 1/1 [==============================] - 0s 14ms/step
# Sorry, I didn't get you, can you please ask in another way?
# medicin
# 1/1 [==============================] - 0s 14ms/step
# Sorry, I didn't get you, can you please ask in another way?
# protecting
# 1/1 [==============================] - 0s 19ms/step
# Sorry, I didn't get you, can you please ask in another way?
# how can I avoid corona
# 1/1 [==============================] - 0s 15ms/step
# The virus enters your body via your eyes, nose and/or mouth, so it is important to avoid touching your face with unwashed hands. Washing of hands with soap and water for at least 20 seconds, or cleaning hands thoroughly with alcohol-based solutions, gels or tissues is recommended in all settings. It is also recommended to stay one metre or more away from people infected with COVID-19 who are showing symptoms, to reduce the risk of infection through respiratory droplets.
# how
# 1/1 [==============================] - 0s 15ms/step
# Sorry, I didn't get you, can you please ask in another way?
# what are the main symptoms?
# 1/1 [==============================] - 0s 24ms/step
# You can have it and display no symptoms depending on your age, how strong your immune system is and how recently you have been exposed. Because it is extremely contagious, the virus can be transmitted easily - even by individuals without symptoms - which is why it is important to practice preventative measures even if you feel fine.
# treatment
# 1/1 [==============================] - 0s 29ms/step
# Sorry, I didn't get you, can you please ask in another way?
# die
# 1/1 [==============================] - 0s 14ms/step
# Sorry, I didn't get you, can you please ask in another way?
# age
# 1/1 [==============================] - 0s 15ms/step
# Sorry, I didn't get you, can you please ask in another way?
# can i die
# 1/1 [==============================] - 0s 22ms/step
# "No, you should not be visiting family members who do not live in your home. You should keep in touch with them using phone or video calls. Where your relatives are elderly or vulnerable, you may leave your house to help them, for example by dropping shopping or medication at their door. You can also help them to order online."
# what are the treatment of covid?
# 1/1 [==============================] - 0s 16ms/step
# Travel has been shown to facilitate the spread of COVID-19 from affected to unaffected areas. Travel and trade restrictions during a public health event of international concern (PHEIC) are regulated under the International Health Regulations (IHR), part III. On 16 March, in an effort to slow the spread of the corona virus, the European Union leaders agreed to a temporary restriction on non-essential travel from third countries into the EU area by closing its borders for the next 30 days staring on 17 March 2020 The temporary travel restriction foresees exemptions for nationals of all EU Member States and Schengen Associated States (Iceland, Liechtenstein, Norway and Switzerland; whilst UK nationals are still to be treated in the same way as EU citizens until end 2020), for the purposes of returning to their homes. Exceptions are also foreseen for travellers with an essential function or need. In addition, most EU countries have also applied national borders closure and/or border checks and travel and transport restrictions or bans within their national borders and between different regions as a measure to slow the spread. See the measures implemented by EU Member States. Many EU countries have also encouraged their citizens to return home (with recommendations  for 14 days self-quarantine upon return) but also recommended that travellers avoid non-essential travels to areas with transmission of COVID-19.
# exit
